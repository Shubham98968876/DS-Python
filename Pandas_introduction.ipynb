# %%
import pandas as pd

# %%
dir(pd)

# %%
df=pd.read_csv('/content/sample_data/california_housing_train.csv')  #dataset available

# %%
df.head(15)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# 5     -114.58     33.63                29.0       1387.0           236.0
# 6     -114.58     33.61                25.0       2907.0           680.0
# 7     -114.59     34.83                41.0        812.0           168.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 9     -114.60     34.83                46.0       1497.0           309.0
# 10    -114.60     33.62                16.0       3741.0           801.0
# 11    -114.60     33.60                21.0       1988.0           483.0
# ...

# %%
df.tail(15)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16985    -124.19     40.77                30.0       2975.0           634.0
# 16986    -124.19     40.73                21.0       5694.0          1056.0
# 16987    -124.21     41.77                17.0       3461.0           722.0
# 16988    -124.21     41.75                20.0       3810.0           787.0
# 16989    -124.21     40.75                32.0       1218.0           331.0
# 16990    -124.22     41.73                28.0       3003.0           699.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16992    -124.23     40.81                52.0       1112.0           209.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# ...

# %%
# first upload salaries.csv
#df=pd.read_csv('/content/Salaries.csv')
df=pd.read_csv("Salaries.csv")

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.head(34)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df['rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.phd.describe
# Out:
# <bound method NDFrame.describe of 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64>

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean()
# Out:
# <ipython-input-26-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-27-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
df.std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df_50=df.head(50)

# %%
df_50.mean()
# Out:
# <ipython-input-30-abcf5df04292>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_50.mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.head(50).mean()
# Out:
# <ipython-input-31-56442511a41d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.head(50).mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
#Selecting a column
df.salary #does not work if volumn name contains blank space or dot(eg."No. of Columns")
# for that enclose column name inside square bracket.
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df["salary"] # will work if column name has blank  space of dot eg. df["NO. of columns"]
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
result1 = df.salary
result1
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
# 2 data structure  in pandas: 1.series 2.dataframe
# Pandas series : is one-dimentional labeled array whose objecct size cannot be changed.
# pandas Dataframe: is a two-dimentional structure with coloumns and rows whose size can be changed.
# you can also think of it as a dictionary of series objects.
type(result1)
# Out:
# pandas.core.series.Series

# %%
result2=df[['salary']]

# %%
result2
# Out:
#     salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# 74  104542
# 75  124312
# 76  109954
# 77  109646
#
# [78 rows x 1 columns]

# %%
import pandas as pd

# %%
df=pd.read_csv("Salaries.csv")

# %%
# Extract particular coloumn in a  new dataframe
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
newdf=df[['salary','service','phd']]
newdf
# Out:
#     salary  service  phd
# 0   186960       49   56
# 1    93000        6   12
# 2   110515       20   23
# 3   131205       31   40
# 4   104800       18   20
# ..     ...      ...  ...
# 73  105450       10   18
# 74  104542        6   19
# 75  124312       17   17
# 76  109954       14   28
# 77  109646       15   23
#
# [78 rows x 3 columns]

# %%
# value_counts()
df['discipline'].value_counts() #catagory and its value
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df['phd'].value_counts()
# Out:
# 4     6
# 17    5
# 20    5
# 12    5
# 23    4
# 18    4
# 29    3
# 25    3
# 28    3
# 3     2
# 5     2
# 11    2
# 7     2
# 45    2
# 10    2
# 2     2
# 13    2
# 19    2
# 8     2
# 35    2
# 36    2
# 39    2
# 14    1
# 26    1
# 56    1
# 30    1
# 27    1
# 22    1
# 9     1
# 21    1
# 38    1
# 33    1
# 1     1
# 51    1
# 40    1
# 24    1
# Name: phd, dtype: int64

# %%
df.phd.mean()
# Out:
# 19.705128205128204

# %%
# in ran 3 values: Asso,Asst,prof. group ny this and find mean of each category
df.groupby(['rank']).mean() # group by rank and finds means of all numeric columns
# Out:
# <ipython-input-18-fc14e4254697>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['rank']).mean() # group by rank and finds means of all numeric columns
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby(['sex']).mean()
# Out:
# <ipython-input-19-f1f0eb4b7e52>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['sex']).mean()
#               phd    service         salary
# sex
# Female  16.512821  11.564103  101002.410256
# Male    22.897436  18.538462  115045.153846

# %%
df['sex'].value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %%
df.groupby(['sex']).count()
# Out:
#         rank  discipline  phd  service  salary
# sex
# Female    39          39   39       39      39
# Male      39          39   39       39      39

# %%
df.groupby(['discipline']).count()
# Out:
#             rank  phd  service  sex  salary
# discipline
# A             36   36       36   36      36
# B             42   42       42   42      42

# %%
df.groupby(["discipline","rank"]).count()
# Out:
#                       phd  service  sex  salary
# discipline rank
# A          AssocProf    5        5    5       5
#            AsstProf     8        8    8       8
#            Prof        23       23   23      23
# B          AssocProf    8        8    8       8
#            AsstProf    11       11   11      11
#            Prof        23       23   23      23

# %%
df.groupby(['discipline','rank','sex']).count()
# Out:
#                              phd  service  salary
# discipline rank      sex
# A          AssocProf Female    4        4       4
#                      Male      1        1       1
#            AsstProf  Female    6        6       6
#                      Male      2        2       2
#            Prof      Female    8        8       8
#                      Male     15       15      15
# B          AssocProf Female    6        6       6
#                      Male      2        2       2
#            AsstProf  Female    5        5       5
#                      Male      6        6       6
#            Prof      Female   10       10      10
#                      Male     13       13      13

# %%
df.groupby(["discipline","rank"]).mean()
# Out:
# <ipython-input-27-9754cc04bbcf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["discipline","rank"]).mean()
#                             phd    service         salary
# discipline rank
# A          AssocProf  18.800000  15.800000   73959.800000
#            AsstProf    4.375000   2.125000   74450.000000
#            Prof       28.086957  20.434783  111935.695652
# B          AssocProf  12.750000   8.500000  102927.750000
#            AsstProf    5.545455   2.272727   86390.272727
#            Prof       26.043478  22.391304  135313.913043

# %%
df.groupby(['discipline','rank','sex']).mean()
# Out:
#                                    phd    service         salary
# discipline rank      sex
# A          AssocProf Female  18.500000  15.500000   72128.500000
#                      Male    20.000000  17.000000   81285.000000
#            AsstProf  Female   4.833333   2.500000   72933.333333
#                      Male     3.000000   1.000000   79000.000000
#            Prof      Female  26.500000  16.125000  109631.875000
#                      Male    28.933333  22.733333  113164.400000
# B          AssocProf Female  13.500000   8.833333   99435.666667
#                      Male    10.500000   7.500000  113404.000000
#            AsstProf  Female   6.600000   2.600000   84189.800000
#                      Male     4.666667   2.000000   88224.000000
#            Prof      Female  21.500000  17.900000  131836.200000
#                      Male    29.538462  25.846154  137989.076923

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
grouped = df.groupby('rank') # saving in variable grouped

# %%
from numba.misc.special import gdb
for g in grouped: # to display records of grouped variable
  print(g)
# Out:
# ('AssocProf',          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 41  AssocProf          A   13        8  Female   74830
# 47  AssocProf          B   11       11  Female  103613
# 54  AssocProf          A   25       22  Female   62884
# 56  AssocProf          A   10        8  Female   77500
# 59  AssocProf          B   12       10  Female  103994
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 64  AssocProf          A   26       24  Female   73300
# 71  AssocProf          B   12        9  Female   71065
# 74  AssocProf          B   19        6  Female  104542)
# ('AsstProf',         rank discipline  phd  service     sex  salary
# 12  AsstProf          B    1        0    Male   88000
# 16  AsstProf          B    8        3    Male   75044
# ...

# %%
df[df.salary>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df.shape
# Out:
# (78, 6)

# %%
df.shape[0]
# Out:
# 78

# %%
df[df.salary>120000].shape[0]
# Out:
# 25

# %%
df[df.salary>120000].count()
# Out:
# rank          25
# discipline    25
# phd           25
# service       25
# sex           25
# salary        25
# dtype: int64

# %%
newdf = df[( df['sex']=='Male') & (df['salary']>150000)]
newdf
# Out:
#     rank discipline  phd  service   sex  salary
# 0   Prof          B   56       49  Male  186960
# 13  Prof          B   35       33  Male  162200
# 14  Prof          B   25       19  Male  153750
# 15  Prof          B   17        3  Male  150480
# 19  Prof          A   29       27  Male  150500
# 27  Prof          A   45       43  Male  155865
# 31  Prof          B   22       21  Male  155750

# %%
# newdf.count()
# OR
newdf.shape[0]
# Out:
# 7

# %%
df[df['rank'] != 'prof'].shape[0]
# Out:
# 78

# %%
df[(df['service']>15) | (df['salary']>100000)].shape[0]
# Out:
# 54

# %%
df # will display all records
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
# to extract only particular index rcord - say 5th index record
df[5]

# %%
df.iloc[5] # iloc -> index location for row
# Out:
# rank            Prof
# discipline         A
# phd               20
# service           20
# sex             Male
# salary        122400
# Name: 5, dtype: object

# %%
df.iloc[1:4, 0:3] #  row  1 to 3 , col 0 to 2
# Out:
#    rank discipline  phd
# 1  Prof          A   12
# 2  Prof          A   23
# 3  Prof          A   40

# %%
df.iloc[0:9 , 0:3] # o to 9 record and 0 to 2 columns
# Out:
#         rank discipline  phd
# 0       Prof          B   56
# 1       Prof          A   12
# 2       Prof          A   23
# 3       Prof          A   40
# 4       Prof          B   20
# 5       Prof          A   20
# 6  AssocProf          A   20
# 7       Prof          A   18
# 8       Prof          A   29

# %%
df.iloc[0:2,] # row o to 1 and all col
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.iloc[:,4] # all rows , index 4
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#        ...
# 73    Female
# 74    Female
# 75    Female
# 76    Female
# 77    Female
# Name: sex, Length: 78, dtype: object

# %%
df.iloc[[10,20,22,24],] # only particular rows with all columns
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 20  AsstProf          B    4        4  Male   92000
# 22  AsstProf          A    4        2  Male   73000
# 24      Prof          A   30       23  Male   91100

# %%
df.loc[:,['rank','sex']] # without mentioning index no - mention col name
# Out:
#          rank     sex
# 0        Prof    Male
# 1        Prof    Male
# 2        Prof    Male
# 3        Prof    Male
# 4        Prof    Male
# ..        ...     ...
# 73       Prof  Female
# 74  AssocProf  Female
# 75       Prof  Female
# 76       Prof  Female
# 77       Prof  Female
#
# [78 rows x 2 columns]

# %%
df.loc[[0,1,2],['discipline','rank']]
# Out:
#   discipline  rank
# 0          B  Prof
# 1          A  Prof
# 2          A  Prof

# %%
df.iloc[::5] # all rows and coloumns with step value 5
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 5        Prof          A   20       20    Male  122400
# 10       Prof          B   39       33    Male  128250
# 15       Prof          B   17        3    Male  150480
# 20   AsstProf          B    4        4    Male   92000
# 25       Prof          B   35       31    Male   99418
# 30  AssocProf          B    9        7    Male  107008
# 35       Prof          B   28       23    Male  126933
# 40       Prof          A   39       36  Female  137000
# 45       Prof          B   25       25  Female  140096
# 50   AsstProf          B   10        5  Female   97032
# 55   AsstProf          A    2        0  Female   72500
# 60   AsstProf          B    3        3  Female   92000
# 65       Prof          A   36       19  Female  117555
# 70   AsstProf          A    8        3  Female   78500
# 75       Prof          B   17       17  Female  124312

# %%
df.iloc[10:30:4]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 14      Prof          B   25       19  Male  153750
# 18      Prof          A   19        7  Male  107300
# 22  AsstProf          A    4        2  Male   73000
# 26      Prof          A   38       19  Male  148750

# %%
df.iloc[::-1] # all record in reverce order
# Out:
#          rank discipline  phd  service     sex  salary
# 77       Prof          A   23       15  Female  109646
# 76       Prof          A   28       14  Female  109954
# 75       Prof          B   17       17  Female  124312
# 74  AssocProf          B   19        6  Female  104542
# 73       Prof          B   18       10  Female  105450
# ..        ...        ...  ...      ...     ...     ...
# 4        Prof          B   20       18    Male  104800
# 3        Prof          A   40       31    Male  131205
# 2        Prof          A   23       20    Male  110515
# 1        Prof          A   12        6    Male   93000
# 0        Prof          B   56       49    Male  186960
#
# [78 rows x 6 columns]

# %%
dir(df) # functions applies on function
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
# common aggregation function that applies  are: min,max count,sum,prod,mean,median,mode,mad,std
df[['phd','salary']].agg(['min','max','mean','mad','std'])
# Out:
# <ipython-input-64-8cc9efc7ca60>:2: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   df[['phd','salary']].agg(['min','max','mean','mad','std'])
# <ipython-input-64-8cc9efc7ca60>:2: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   df[['phd','salary']].agg(['min','max','mean','mad','std'])
#             phd         salary
# min    1.000000   57800.000000
# max   56.000000  186960.000000
# mean  19.705128  108023.782051
# mad    9.920776   22957.266930
# std   12.498425   28293.661022

# %%
df[['phd','salary']].agg("skew")
# Out:
# phd       0.634366
# salary    0.452103
# dtype: float64

# %%
df[['salary']].agg('kurt')
# Out:
# salary   -0.401713
# dtype: float64

# %%
df.var()
# Out:
# <ipython-input-70-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# phd        1.562106e+02
# service    1.473740e+02
# salary     8.005313e+08
# dtype: float64

# %%
df.sem() # std error of mean
